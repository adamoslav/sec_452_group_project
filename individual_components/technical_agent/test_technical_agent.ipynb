# %% [markdown]
# # Test Technical agent

# %% [markdown]
# ### import class

# %%
from technical_agent import technical_agent


activate_class = technical_agent('AAPL', 2020)
predict = activate_class.model_prediction()
print(predict)
# Out:
# Class imported successfully!
# Class activated!
# [*********************100%***********************]  1 of 1 completed
#             Sell_prob  Hold_prob  Buy_prob  predict_action  confidence_level
# Date
# 2020-01-02      0.106      0.528     0.366               0             0.528
# 2020-01-03      0.066      0.410     0.524               1             0.524
# 2020-01-06      0.186      0.574     0.240               0             0.574
# 2020-01-07      0.026      0.498     0.476               0             0.498
# 2020-01-08      0.150      0.618     0.232               0             0.618
# ...               ...        ...       ...             ...               ...
# 2020-12-23      0.286      0.300     0.414               1             0.414
# 2020-12-24      0.258      0.380     0.362               0             0.380
# 2020-12-28      0.294      0.458     0.248               0             0.458
# 2020-12-29      0.222      0.296     0.482               1             0.482
# ...
