# %% [markdown]
# # Test
# This script imports the `.py` file with `data_preparation` class from `data_prep_class.py`and will run tests on the class to create training and simulation datasets for each agent.

# %% [markdown]
# ## Importing the Class

# %%
# importing the class
from data_prep_class import data_preparation

print("Class imported successfully!")
# Out:
# Class imported successfully!

# %% [markdown]
# ## Activating the Class
# Test case with `AAPL` (Apple) company and `simuluation year` being 2020.

# %%
# activating the class 
activate_class = data_preparation("AAPL", 2020)

print("Class activated!")
# Out:
# Class activated!

# %% [markdown]
# ## Datasets

# %% [markdown]
# ### Technical Agent's Training Data

# %%
# technical agent's training data
technical_agent_training = activate_class.train_data_technical_agent()

# printing the data
technical_agent_training
# Out:
# [*********************100%***********************]  1 of 1 completed
#             moving_average_10_day  daily_price_change  \
# Date
# 2018-01-02              40.806047           -0.491341
# 2018-01-03              40.806047            0.070193
# 2018-01-04              40.806047           -0.114648
# 2018-01-05              40.806047           -0.364997
# 2018-01-08              40.806047            0.000000
# ...                           ...                 ...
# 2019-12-23              66.755757           -0.836457
# 2019-12-24              67.136378            0.101246
# 2019-12-26              67.597757           -1.226963
# 2019-12-27              68.039849            0.318193
# 2019-12-30              68.434456           -0.496570
#
#             daily_price_fluctuation  volatility  volatility_change  \
# Date
# 2018-01-02                 0.711280        9.77           1.549999
# 2018-01-03                 0.605989        9.15           0.710000
# ...

# %% [markdown]
# ### Technical Agent's Simulation Data

# %%
# technical agent's simulation data
technical_agent_simulation = activate_class.simulation_data_technical_agent()

# printing the data
technical_agent_simulation
# Out:
#             moving_average_10_day  daily_price_change  \
# Date
# 2020-01-02              73.764879           -0.990735
# 2020-01-03              73.764879           -0.067495
# 2020-01-06              73.764879           -1.448728
# 2020-01-07              73.764879            0.349524
# 2020-01-08              73.764879           -1.453554
# ...                           ...                 ...
# 2020-12-23             123.469109            1.167048
# 2020-12-24             124.318136           -0.632146
# 2020-12-28             125.706927           -2.625861
# 2020-12-29             126.979987            3.092693
# 2020-12-30             127.547949            1.808929
#
#             daily_price_fluctuation  volatility  volatility_change  \
# Date
# 2020-01-02                 1.304102   12.470000           1.300000
# 2020-01-03                 0.983496   14.020000           3.070001
# 2020-01-06                 1.737996   13.850000           2.849999
# ...

# %% [markdown]
# ### Health Agent's Training Data

# %%
# health agent's train data
health_agent_training = activate_class.train_data_health_agent()

# printing the data
health_agent_training
# Out:
# [*********************100%***********************]  1 of 1 completed
#             revenue_growth   net_income  profit_margin  debt_to_equity_ratio  \
# Date
# 2018-01-02        0.679245  20065000000       0.227255              1.901547
# 2018-01-03        0.679245  20065000000       0.227255              1.901547
# 2018-01-04        0.679245  20065000000       0.227255              1.901547
# 2018-01-05        0.679245  20065000000       0.227255              1.901547
# 2018-01-08        0.679245  20065000000       0.227255              1.901547
# ...                    ...          ...            ...                   ...
# 2019-12-23        0.190135  13686000000       0.213710              2.741004
# 2019-12-24        0.190135  13686000000       0.213710              2.741004
# 2019-12-26        0.190135  13686000000       0.213710              2.741004
# 2019-12-27        0.190135  13686000000       0.213710              2.741004
# ...

# %% [markdown]
# ### Health Agent's Simulation Data

# %%
# health agent's train data
health_agent_simulation = activate_class.simulation_data_health_agent()

# printing the data
health_agent_simulation
# Out:
#             revenue_growth   net_income  profit_margin  debt_to_equity_ratio  \
# Date
# 2020-01-02        0.000000  22236000000       0.242172              2.804470
# 2020-01-03        0.000000  22236000000       0.242172              2.804470
# 2020-01-06        0.000000  22236000000       0.242172              2.804470
# 2020-01-07        0.000000  22236000000       0.242172              2.804470
# 2020-01-08        0.000000  22236000000       0.242172              2.804470
# ...                    ...          ...            ...                   ...
# 2020-12-23        0.083991  12673000000       0.195879              3.957039
# 2020-12-24        0.083991  12673000000       0.195879              3.957039
# 2020-12-28        0.083991  12673000000       0.195879              3.957039
# 2020-12-29        0.083991  12673000000       0.195879              3.957039
# 2020-12-30        0.083991  12673000000       0.195879              3.957039
#
# ...
