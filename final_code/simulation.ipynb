# %% [markdown]
# # Simulation
# All following simulations have `technical` agent as the standalone agent, and the system is compared to the `sentiment` agent whose **weight** is reduced.

# %%
# importing plotting agent
from plotting_agent import plotting_agent

print("Plotting agent imported successfully!")
# Out:
# Plotting agent imported successfully!

# %% [markdown]
# ## Company 1: `Boeing Co`

# %% [markdown]
# ### Simulation 1: Year `2016`
# Annual change for year `2016` was `+11.31%`

# %%
visualizer = plotting_agent("BA", 2016,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: 26.48%
# Technical Agent return: -5.51%
# Baseline Approach return: 14.48%
#
# ...
#
# MAS Sharpe Ratio: 1.4299
# Technical Agent Sharpe Ratio: -0.2844
# Baseline Approach Sharpe Ratio: 0.6145
#
# ...
# MAS Maximum Drawdown: -11.40%
# Technical Agent Maximum Drawdown: -22.32%
# Baseline Approach Maximum Drawdown: -22.32%

# %% [markdown]
# ### Simulation 2: Year `2017`
# Annual change for year `2017` was `+94.71%`

# %%
visualizer = plotting_agent("BA", 2017,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: 14.73%
# Technical Agent return: 17.43%
# Baseline Approach return: 92.83%
#
# ...
#
# MAS Sharpe Ratio: 1.8830
# Technical Agent Sharpe Ratio: 2.1789
# Baseline Approach Sharpe Ratio: 3.7244
#
# ...
# MAS Maximum Drawdown: -1.19%
# Technical Agent Maximum Drawdown: -1.19%
# Baseline Approach Maximum Drawdown: -4.50%

# %% [markdown]
# ### Simulation 3: Year `2020`
# Annual change for year `2020` was `-33.90%`

# %%
visualizer = plotting_agent("BA", 2020,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: 67.04%
# Technical Agent return: -35.71%
# Baseline Approach return: -34.40%
#
# ...
#
# MAS Sharpe Ratio: 1.0311
# Technical Agent Sharpe Ratio: -0.0869
# Baseline Approach Sharpe Ratio: -0.0662
#
# ...
# MAS Maximum Drawdown: -37.32%
# Technical Agent Maximum Drawdown: -72.23%
# Baseline Approach Maximum Drawdown: -72.08%

# %% [markdown]
# ## Company 2: `Apple Inc.`

# %% [markdown]
# ### Simulation 1: Year `2016`
# Annual change for year `2016` was `+12.48%`

# %%
visualizer = plotting_agent("AAPL", 2016,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: 8.14%
# Technical Agent return: 5.37%
# Baseline Approach return: 12.37%
#
# ...
#
# MAS Sharpe Ratio: 0.3808
# Technical Agent Sharpe Ratio: 0.2677
# Baseline Approach Sharpe Ratio: 0.5403
#
# ...
# MAS Maximum Drawdown: -18.90%
# Technical Agent Maximum Drawdown: -15.43%
# Baseline Approach Maximum Drawdown: -18.90%

# %% [markdown]
# ### Simulation 2: Year `2017`
# Annual change for year `2017` was `+48.46%`

# %%
visualizer = plotting_agent("AAPL", 2017,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: 17.68%
# Technical Agent return: 6.54%
# Baseline Approach return: 47.99%
#
# ...
#
# MAS Sharpe Ratio: 2.0597
# Technical Agent Sharpe Ratio: 1.4481
# Baseline Approach Sharpe Ratio: 2.1953
#
# ...
# MAS Maximum Drawdown: -0.59%
# Technical Agent Maximum Drawdown: 0.00%
# Baseline Approach Maximum Drawdown: -8.85%

# %% [markdown]
# ### Simulation 3: Year `2022`
# Annual change for year `2022` was `-26.40%`

# %%
visualizer = plotting_agent("AAPL", 2022,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: -21.68%
# Technical Agent return: -26.17%
# Baseline Approach return: -28.13%
#
# ...
#
# MAS Sharpe Ratio: -0.6815
# Technical Agent Sharpe Ratio: -1.0662
# Baseline Approach Sharpe Ratio: -0.8396
#
# ...
# MAS Maximum Drawdown: -24.02%
# Technical Agent Maximum Drawdown: -28.28%
# Baseline Approach Maximum Drawdown: -30.27%

# %% [markdown]
# ## Company 3: `Tesla Inc.`

# %% [markdown]
# ### Simulation 1: Year `2018`
# Annual change for year `2018` was `+6.89%`

# %%
visualizer = plotting_agent("TSLA", 2018,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: 58.98%
# Technical Agent return: -30.42%
# Baseline Approach return: 4.16%
#
# ...
#
# MAS Sharpe Ratio: 1.0800
# Technical Agent Sharpe Ratio: -0.5873
# Baseline Approach Sharpe Ratio: 0.3069
#
# ...
# MAS Maximum Drawdown: -22.38%
# Technical Agent Maximum Drawdown: -38.71%
# Baseline Approach Maximum Drawdown: -33.96%

# %% [markdown]
# ### Simulation 2: Year `2020`
# Annual change for year `2020` was `+743.43%`

# %%
visualizer = plotting_agent("TSLA", 2020,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: 41.77%
# Technical Agent return: -11.10%
# Baseline Approach return: 707.14%
#
# ...
#
# MAS Sharpe Ratio: 1.2241
# Technical Agent Sharpe Ratio: -0.1526
# Baseline Approach Sharpe Ratio: 2.7876
#
# ...
# MAS Maximum Drawdown: -18.83%
# Technical Agent Maximum Drawdown: -44.00%
# Baseline Approach Maximum Drawdown: -60.62%

# %% [markdown]
# ### Simulation 3: Year `2022`
# The annual change for year `2022` was `-65.03%`

# %%
visualizer = plotting_agent("TSLA", 2022,  20000, "technical", "sentiment")
visualizer.plot_results()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Device set to use mps:0
# MAS return: -69.04%
# Technical Agent return: -47.02%
# Baseline Approach return: -69.19%
#
# ...
#
# MAS Sharpe Ratio: -1.5348
# Technical Agent Sharpe Ratio: -1.3227
# Baseline Approach Sharpe Ratio: -1.5259
#
# ...
# MAS Maximum Drawdown: -72.56%
# Technical Agent Maximum Drawdown: -54.02%
# Baseline Approach Maximum Drawdown: -72.71%
